# %%
import numpy as np
import pandas as pd
import pandas.io.data as web

# %%
goog = web.DataReader('GOOG',data_source='google',start='3/14/2009',end='4/14/2015')

# %%
goog.tail()
# Out:
#               Open    High     Low   Close   Volume
# ﻿Date
# 2015-04-08  538.38  543.85  538.38  541.61  1175332
# 2015-04-09  541.03  541.95  535.49  540.78  1553586
# 2015-04-10  542.29  542.29  537.31  540.01  1405574
# 2015-04-13  538.41  544.06  537.31  539.17  1640809
# 2015-04-14  536.25  537.57  528.09  530.39  2597043
#
# [5 rows x 5 columns]

# %%
goog['Log_Ret'] = np.log(goog['Close'] / goog['Close'].shift(1))
goog['Volatility'] = pd.rolling_std(goog['Log_Ret'],window=252) * np.sqrt(252)

# %%
# %matplotlib inline
goog[['Close','Volatility']].plot(subplots=True,color='blue',figsize=(8,6))
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x10f896090>,
#        <matplotlib.axes.AxesSubplot object at 0x10f8ee6d0>], dtype=object)
